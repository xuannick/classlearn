# %% [markdown]
# ## 基础语法

# %% [markdown]
# - 声明变量

# %%
a=123

# %% [markdown]
# - 变量命名格式，只能字母、数字、下划线

# %%
nick=1
chali=2
_nick=3
_chali=4
n1=5

# %% [markdown]
# - 赋值：变量名=变量值，左边赋值到右边

# %%
a=1
b=1.2
c="word"
d='wordd'
e=False
f=True

# %% [markdown]
# 注：Fasle和Ture是布尔值

# %% [markdown]
# - 四种复合数据类型

# %% [markdown]
# 列表：

# %%
a=[1,3,4]

# %% [markdown]
# 集合：

# %%
b={1,3,4}

# %% [markdown]
# 元组：

# %%
c=(1,3,4)

# %% [markdown]
# 字典：

# %%
d={'n':1,'b':2}

# %% [markdown]
# - 输出

# %% [markdown]
# 输出一段话：

# %%
print("hello world")

# %% [markdown]
# 输出一个变量的值：

# %%
 a=15

# %% [raw]
# print(a)

# %% [markdown]
# 输出一段固定的话、话中含有一个变量：

# %%
a=12

# %%
print(f"hello {a}")

# %% [markdown]
#     或者：

# %%
a=12

# %%
print("hello %d" % a)
# Out:
# hello 12

# %% [markdown]
# 长空格：\t

# %%
print("我是0\t我是1")
# Out:
# 我是0	我是1

# %% [markdown]
# 换行：\n

# %%
print("我是0\n我是1")
# Out:
# 我是0
# 我是1

# %% [markdown]
# 想要输出不换行：, end=""

# %%
print("我是0我是1",end="")
# Out:
# 我是0我是1

# %% [markdown]
# 想要运行时，输入一个值给变量：

# %%
a=input()
# Out:
#  1

# %% [markdown]
#     也可以这样写：

# %%
a=input("请输入：")
# Out:
# 请输入： 1

# %% [markdown]
#     转换类型，以免出错：

# %%
a=int(input("请输入："))
# Out:
# 请输入： 1

# %% [markdown]
# 想要转换某个变量的类型，用其他类型的表示（变量）：

# %%
a=15

# %%
b=str(a)

# %%
c=float(b)

# %% [markdown]
# 获得随机数：

# %% [markdown]
#     从1到100，随机整数：

# %%
import random

# %%
a=random.randint(1,100)

# %%
print(a)
# Out:
# 74

# %% [markdown]
#     从1到100，随机数，包括小数

# %%
import random

# %%
a=random.uniform(1,100)

# %%
print(a)
# Out:
# 29.686896484597106

# %% [markdown]
#     从0到1，随机数，包括小数

# %%
import random

# %%
a=random.random()

# %%
print(a)
